# %%
# !mageck -h
# Out:
# usage: mageck [-h] [-v] {count,test,pathway,plot,mle} ...
#
# mageck: performs sgRNA, gene and pathway analysis on CRISPR-Cas9 screening
# data.
#
# positional arguments:
#   {count,test,pathway,plot,mle}
#                         commands to run mageck
#     count               Collecting read counts from fastq files.
#     test                Perform statistical test from a given count table
#                         (generated by count command).
#     pathway             Perform significant pathway analysis from gene
#                         rankings generated by the test command.
#     plot                Generating graphics for selected genes.
#     mle                 Perform MLE estimation of gene essentiality.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -v, --version         show program's version number and exit

# %%
# !mageck pathway -h
# Out:
# usage: mageck pathway [-h] --gene-ranking GENE_RANKING --gmt-file GMT_FILE
#                       [-n OUTPUT_PREFIX] [--method {gsea,rra}]
#                       [--single-ranking] [--sort-criteria {neg,pos}]
#                       [--keep-tmp] [--ranking-column RANKING_COLUMN]
#                       [--ranking-column-2 RANKING_COLUMN_2]
#                       [--pathway-alpha PATHWAY_ALPHA]
#                       [--permutation PERMUTATION]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --gene-ranking GENE_RANKING
#                         The gene summary file (containing both positive and
#                         negative selection tests) generated by the gene test
#                         step. Pathway enrichment will be performed in both
#                         directions.
#   --gmt-file GMT_FILE   The pathway file in GMT format.
#   -n OUTPUT_PREFIX, --output-prefix OUTPUT_PREFIX
# ...

# %%
# !mageck test -h
# Out:
# usage: mageck test [-h] -k COUNT_TABLE
#                    (-t TREATMENT_ID | --day0-label DAY0_LABEL) [-c CONTROL_ID]
#                    [--paired] [--norm-method {none,median,total,control}]
#                    [--gene-test-fdr-threshold GENE_TEST_FDR_THRESHOLD]
#                    [--adjust-method {fdr,holm,pounds}]
#                    [--variance-estimation-samples VARIANCE_ESTIMATION_SAMPLES]
#                    [--sort-criteria {neg,pos}]
#                    [--remove-zero {none,control,treatment,both,any}]
#                    [--remove-zero-threshold REMOVE_ZERO_THRESHOLD]
#                    [--pdf-report]
#                    [--gene-lfc-method {median,alphamedian,mean,alphamean,secondbest}]
#                    [-n OUTPUT_PREFIX]
#                    [--control-sgrna CONTROL_SGRNA | --control-gene CONTROL_GENE]
#                    [--normcounts-to-file] [--skip-gene SKIP_GENE] [--keep-tmp]
# ...

# %%
ls
# Out:
# DAOY_corCounts.csv*
# MAGeCK RRA.ipynb
# SMB21_corCounts.csv*
# human_pan_species_essential_sgRNAs.txt*
# human_pan_species_nonessential_sgRNAs.txt*
# mouse_pan_species_essential_sgRNAs.txt*
# mouse_pan_species_nonessential_sgRNAs.txt*
# pan_species_control_essentials_genes.xlsx*
# pan_species_control_nonessentials_genes.xlsx*

# %% [markdown]
# MAGeCK RRA for DAOY

# %%
# !mageck test -k DAOY_corCounts.csv -t 1 -c 0 -n DAOY --norm-method none --control-sgrna human_pan_species_nonessential_sgRNAs.txt
# Out:
# INFO  @ Wed, 13 Dec 2023 17:50:47: Parameters: /Users/lab/opt/anaconda3/bin/mageck test -k DAOY_corCounts.csv -t 1 -c 0 -n DAOY --norm-method none --control-sgrna human_pan_species_nonessential_sgRNAs.txt
# INFO  @ Wed, 13 Dec 2023 17:50:47: Welcome to MAGeCK v0.5.9.5. Command: test
# INFO  @ Wed, 13 Dec 2023 17:50:47: Loading count table from DAOY_corCounts.csv
# INFO  @ Wed, 13 Dec 2023 17:50:47: Processing 1 lines..
# INFO  @ Wed, 13 Dec 2023 17:50:47: Loaded 75879 records.
# INFO  @ Wed, 13 Dec 2023 17:50:47: 199 out of 199 control sgRNAs are found in count table.
# INFO  @ Wed, 13 Dec 2023 17:50:47: Loading Rnw template file: /Users/lab/opt/anaconda3/lib/python3.9/site-packages/mageck/test_report.Rmd.
# INFO  @ Wed, 13 Dec 2023 17:50:47: Loading R template file: /Users/lab/opt/anaconda3/lib/python3.9/site-packages/mageck/plot_template.RTemplate.
# ...

# %% [markdown]
# MAGeCK RRA for SMB21

# %%
ls
# Out:
# DAOY_corCounts.csv*
# MAGeCK RRA DAOY SMB21.ipynb
# SMB21_corCounts.csv*
# human_pan_species_essential_sgRNAs.txt*
# human_pan_species_nonessential_sgRNAs.txt*
# mouse_pan_species_essential_sgRNAs.txt*
# mouse_pan_species_nonessential_sgRNAs.txt*
# pan_species_control_essentials_genes.xlsx*
# pan_species_control_nonessentials_genes.xlsx*

# %%
# !mageck test -k SMB21_corCounts.csv -t 1 -c 0 -n SMB21 --norm-method none --control-sgrna mouse_pan_species_nonessential_sgRNAs.txt
# Out:
# INFO  @ Thu, 14 Dec 2023 10:11:32: Parameters: /Users/lab/opt/anaconda3/bin/mageck test -k SMB21_corCounts.csv -t 1 -c 0 -n SMB21 --norm-method none --control-sgrna mouse_pan_species_nonessential_sgRNAs.txt
# INFO  @ Thu, 14 Dec 2023 10:11:32: Welcome to MAGeCK v0.5.9.5. Command: test
# INFO  @ Thu, 14 Dec 2023 10:11:32: Loading count table from SMB21_corCounts.csv
# INFO  @ Thu, 14 Dec 2023 10:11:32: Processing 1 lines..
# INFO  @ Thu, 14 Dec 2023 10:11:32: Loaded 79633 records.
# INFO  @ Thu, 14 Dec 2023 10:11:32: 192 out of 192 control sgRNAs are found in count table.
# INFO  @ Thu, 14 Dec 2023 10:11:32: Loading Rnw template file: /Users/lab/opt/anaconda3/lib/python3.9/site-packages/mageck/test_report.Rmd.
# INFO  @ Thu, 14 Dec 2023 10:11:32: Loading R template file: /Users/lab/opt/anaconda3/lib/python3.9/site-packages/mageck/plot_template.RTemplate.
# ...
